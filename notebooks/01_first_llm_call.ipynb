# %% [markdown]
# # My First LLM Call
# This notebook demonstrates a basic LLM call using Groq and LangChain.

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## Setting up the LLM

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7,
    api_key=os.getenv("GROQ_API_KEY")
)

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI engineering assistant."),
    ("user", "{question}")
])

chain = prompt | llm | StrOutputParser()
print("Chain ready!")
# Out:
# Chain ready!

# %% [markdown]
# ## Running the LLM Call

# %%
response = chain.invoke({"question": "What is an AI agent and why does it matter?"})
print(response)
# Out:
# An AI agent is a software program that uses artificial intelligence (AI) and machine learning (ML) to perform tasks autonomously, making decisions and taking actions based on its programming, data, and environment. AI agents can be designed to interact with humans, other agents, or the physical world, and they can operate in various domains, such as:
#
# 1. **Virtual assistants**: Like Siri, Alexa, or Google Assistant, which perform tasks, provide information, and answer questions.
# 2. **Autonomous vehicles**: Self-driving cars, drones, or robots that navigate and make decisions in real-time.
# 3. **Chatbots**: Computer programs that simulate human-like conversations, often used for customer support or entertainment.
# 4. **Smart home devices**: Thermostats, lights, or security systems that learn and adapt to a user's preferences and habits.
# 5. **Industrial automation**: AI-powered robots or machines that optimize manufacturing processes, predict maintenance needs, or detect anomalies.
#
# AI agents matter for several reasons:
#
# 1. **Increased efficiency**: AI agents can automate repetitive, mundane, or complex tasks, freeing humans to focus on higher-value activities.
# 2. **Improved decision-making**: AI agents can analyze vast amounts of data, identify patterns, and make informed decisions, often faster and more accurately than humans.
# 3. **Enhanced customer experience**: AI-powered chatbots, virtual assistants, and recommendation systems can provide personalized support, guidance, and interactions.
# 4. **Increased safety**: AI agents can monitor and respond to safety-critical situations, such as autonomous vehicles avoiding accidents or medical diagnosis systems detecting health risks.
# 5. **Innovation and disruption**: AI agents can enable new business models, products, and services, disrupting traditional industries and creating new opportunities.
#
# However, AI agents also raise important considerations, such as:
#
# 1. **Accountability and transparency**: As AI agents make decisions, it's essential to understand how they work, what data they use, and who is responsible for their actions.
# 2. **Ethics and bias**: AI agents can perpetuate biases and discriminate if they are trained on biased data or designed with flawed objectives.
# 3. **Security and privacy**: AI agents can be vulnerable to cyber attacks, and their use of personal data raises concerns about privacy and protection.
#
# As AI agents become increasingly prevalent, it's crucial to develop and deploy them responsibly, ensuring they align with human values, respect individual rights, and contribute to the betterment of society.
